# %% [markdown]
# # QCTAR 2026 hands-on trial notebook
# Run the following cell to check that your Python environment and Qiskit installation are working correctly.
# If the circuit runs and prints the output, you are ready for the workshop.

# %%
# QCTAR Environment Sanity Check

import sys
import qiskit
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

print("Python version:", sys.version.split()[0])
print(sys.executable)
print("Qiskit version:", qiskit.__version__)

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()

sim = AerSimulator()
result = sim.run(transpile(qc, sim), shots=100).result()

print("Counts:", result.get_counts())

print("Everything works — no decoherence detected. See you on the 10th!")
# Out:
# Python version: 3.10.19
# /opt/miniconda3/envs/qctar_qiskit_23/bin/python3.10
# Qiskit version: 2.3.0
# Counts: {'00': 49, '11': 51}
# Everything works — no decoherence detected. See you on the 10th!
